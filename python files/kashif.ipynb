# %%
import pandas as pd

# %%
df = pd.read_csv("boat.csv")

# %%
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.to_csv('new-boat.csv')

# %%
df.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df.min()
# Out:
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_9184/3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# Unnamed: 0         0
# survived           0
# pclass             1
# sex           female
# age             0.42
# sibsp              0
# parch              0
# fare             0.0
# class          First
# who            child
# adult_male     False
# alive             no
# alone          False
# dtype: object

# %%
df.max()
# Out:
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_9184/1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# Unnamed: 0         890
# survived             1
# pclass               3
# sex               male
# age               80.0
# sibsp                8
# parch                6
# fare          512.3292
# class            Third
# who              woman
# adult_male        True
# alive              yes
# alone             True
# dtype: object

# %%
df.tail()
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch   fare embarked  \
# 886         886         0       2    male  27.0      0      0  13.00        S
# 887         887         1       1  female  19.0      0      0  30.00        S
# 888         888         0       3  female   NaN      1      2  23.45        S
# 889         889         1       1    male  26.0      0      0  30.00        C
# 890         890         0       3    male  32.0      0      0   7.75        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True

# %%
df.head(20)
# Out:
#     Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0            0         0       3    male  22.0      1      0   7.2500
# 1            1         1       1  female  38.0      1      0  71.2833
# 2            2         1       3  female  26.0      0      0   7.9250
# 3            3         1       1  female  35.0      1      0  53.1000
# 4            4         0       3    male  35.0      0      0   8.0500
# 5            5         0       3    male   NaN      0      0   8.4583
# 6            6         0       1    male  54.0      0      0  51.8625
# 7            7         0       3    male   2.0      3      1  21.0750
# 8            8         1       3  female  27.0      0      2  11.1333
# 9            9         1       2  female  14.0      1      0  30.0708
# 10          10         1       3  female   4.0      1      1  16.7000
# 11          11         1       1  female  58.0      0      0  26.5500
# ...

# %% [markdown]
# ## Subset row and column

# %%
df.iloc[10:20]

# %%
df.iloc[:, [1, 2, 5]]

# %%
df.iloc[:, 'x2':'x4']

# %%
df.sample(n=6)
# Out:
#      Unnamed: 0  survived  pclass   sex   age  sibsp  parch     fare embarked  \
# 200         200         0       3  male  28.0      0      0   9.5000        S
# 263         263         0       1  male  40.0      0      0   0.0000        S
# 344         344         0       2  male  36.0      0      0  13.0000        S
# 601         601         0       3  male   NaN      0      0   7.8958        S
# 838         838         1       3  male  32.0      0      0  56.4958        S
# 187         187         1       1  male  45.0      0      0  26.5500        S
#
#       class  who  adult_male deck  embark_town alive  alone
# 200   Third  man        True  NaN  Southampton    no   True
# 263   First  man        True    B  Southampton    no   True
# 344  Second  man        True  NaN  Southampton    no   True
# 601   Third  man        True  NaN  Southampton    no   True
# 838   Third  man        True  NaN  Southampton   yes   True
# 187   First  man        True  NaN  Southampton   yes   True

# %%
df.nlargest(7,'age')# get the larget number in age col.
# Out:
#      Unnamed: 0  survived  pclass   sex   age  sibsp  parch     fare embarked  \
# 630         630         1       1  male  80.0      0      0  30.0000        S
# 851         851         0       3  male  74.0      0      0   7.7750        S
# 96           96         0       1  male  71.0      0      0  34.6542        C
# 493         493         0       1  male  71.0      0      0  49.5042        C
# 116         116         0       3  male  70.5      0      0   7.7500        Q
# 672         672         0       2  male  70.0      0      0  10.5000        S
# 745         745         0       1  male  70.0      1      1  71.0000        S
#
#       class  who  adult_male deck  embark_town alive  alone
# 630   First  man        True    A  Southampton   yes   True
# 851   Third  man        True  NaN  Southampton    no   True
# 96    First  man        True    A    Cherbourg    no   True
# 493   First  man        True  NaN    Cherbourg    no   True
# ...

# %%
df.sample(frac=0.5)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch      fare  \
# 296         296         0       3    male  23.5      0      0    7.2292
# 866         866         1       2  female  27.0      1      0   13.8583
# 541         541         0       3  female   9.0      4      2   31.2750
# 22           22         1       3  female  15.0      0      0    8.0292
# 508         508         0       3    male  28.0      0      0   22.5250
# ..          ...       ...     ...     ...   ...    ...    ...       ...
# 616         616         0       3    male  34.0      1      1   14.4000
# 802         802         1       1    male  11.0      1      2  120.0000
# 77           77         0       3    male   NaN      0      0    8.0500
# 45           45         0       3    male   NaN      0      0    8.0500
# 483         483         1       3  female  63.0      0      0    9.5875
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Summarize Data

# %%
df.shape
# Out:
# (891, 16)

# %%
len(df)
# Out:
# 891

# %%
df.value_counts()
# Out:
# Unnamed: 0  survived  pclass  sex     age   sibsp  parch  fare      embarked  class   who    adult_male  deck  embark_town  alive  alone
# 1           1         1       female  38.0  1      0      71.2833   C         First   woman  False       C     Cherbourg    yes    False    1
# 571         1         1       female  53.0  2      0      51.4792   S         First   woman  False       C     Southampton  yes    False    1
# 577         1         1       female  39.0  1      0      55.9000   S         First   woman  False       E     Southampton  yes    False    1
# 581         1         1       female  39.0  1      1      110.8833  C         First   woman  False       C     Cherbourg    yes    False    1
# 583         0         1       male    36.0  0      0      40.1250   C         First   man    True        A     Cherbourg    no     True     1
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df['age'].nunique()
# Out:
# 88

# %%
df.sum()
# Out:
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_9184/1703867807.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum()
# Unnamed: 0                                               396495
# survived                                                    342
# pclass                                                     2057
# sex           malefemalefemalefemalemalemalemalemalefemalefe...
# age                                                    21205.17
# sibsp                                                       466
# parch                                                       340
# fare                                                 28693.9493
# class         ThirdFirstThirdFirstThirdThirdFirstThirdThirdS...
# who           manwomanwomanwomanmanmanmanchildwomanchildchil...
# ...

# %%
df.count()
# Out:
# Unnamed: 0     891
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
df.median()
# Out:
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_9184/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Unnamed: 0    445.0000
# survived        0.0000
# pclass          3.0000
# age            28.0000
# sibsp           0.0000
# parch           0.0000
# fare           14.4542
# adult_male      1.0000
# alone           1.0000
# dtype: float64

# %%
df.quantile([0.05, 0.36])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_9184/2585255753.py in <module>
# ----> 1 df.quantile([0.05, 0.36])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in quantile(self, q, axis, numeric_only, interpolation)
#   10310             return self._constructor_sliced([], index=cols, name=q, dtype=np.float64)
#   10311
# > 10312         res = data._mgr.quantile(qs=q, axis=1, interpolation=interpolation)
#   10313
#   10314         result = self._constructor(res)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in quantile(self, qs, axis, interpolation)
#    1343         new_axes[1] = Float64Index(qs)
#    1344
# -> 1345         blocks = [
#    1346             blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1347             for blk in self.blocks
#
# ...

# %%
df.size
# Out:
# 14256

# %%
df.quantile
# Out:
# <bound method DataFrame.quantile of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.apply
# Out:
# <bound method DataFrame.apply of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.min()
# Out:
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_9184/3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# Unnamed: 0         0
# survived           0
# pclass             1
# sex           female
# age             0.42
# sibsp              0
# parch              0
# fare             0.0
# class          First
# who            child
# adult_male     False
# alive             no
# alone          False
# dtype: object

# %%
df.max()
# Out:
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_9184/1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# Unnamed: 0         890
# survived             1
# pclass               3
# sex               male
# age               80.0
# sibsp                8
# parch                6
# fare          512.3292
# class            Third
# who              woman
# adult_male        True
# alive              yes
# alone             True
# dtype: object

# %%
df.apply()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_9184/3313107436.py in <module>
# ----> 1 df.apply()
#
# TypeError: apply() missing 1 required positional argument: 'func'

# %% [markdown]
# ## Plot

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.scatter(x='class',y='alive')
# Out:
# <AxesSubplot:xlabel='class', ylabel='alive'>

# %% [markdown]
# ## Handling missing data

# %%
df.dropna()
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 1             1         1       1  female  38.0      1      0  71.2833
# 3             3         1       1  female  35.0      1      0  53.1000
# 6             6         0       1    male  54.0      0      0  51.8625
# 10           10         1       3  female   4.0      1      1  16.7000
# 11           11         1       1  female  58.0      0      0  26.5500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 871         871         1       1  female  47.0      1      1  52.5542
# 872         872         0       1    male  33.0      0      0   5.0000
# 879         879         1       1  female  56.0      0      1  83.1583
# 887         887         1       1  female  19.0      0      0  30.0000
# 889         889         1       1    male  26.0      0      0  30.0000
#
#     embarked  class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.fillna(5)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   5.0      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Make New Column

# %%
df.assign()
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.max(axis=1)
# Out:
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_9184/1471452883.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max(axis=1)
# 0       22.0000
# 1       71.2833
# 2       26.0000
# 3       53.1000
# 4       35.0000
#          ...
# 886    886.0000
# 887    887.0000
# 888    888.0000
# 889    889.0000
# 890    890.0000
# Length: 891, dtype: float64

# %%
df.clip()
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.abs
# Out:
# <bound method NDFrame.abs of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.min()
# Out:
# C:\Users\EMBEDD~1\AppData\Local\Temp/ipykernel_9184/3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# Unnamed: 0         0
# survived           0
# pclass             1
# sex           female
# age             0.42
# sibsp              0
# parch              0
# fare             0.0
# class          First
# who            child
# adult_male     False
# alive             no
# alone          False
# dtype: object

# %%
df.shift(1)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0           NaN       NaN     NaN     NaN   NaN    NaN    NaN      NaN
# 1           0.0       0.0     3.0    male  22.0    1.0    0.0   7.2500
# 2           1.0       1.0     1.0  female  38.0    1.0    0.0  71.2833
# 3           2.0       1.0     3.0  female  26.0    0.0    0.0   7.9250
# 4           3.0       1.0     1.0  female  35.0    1.0    0.0  53.1000
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886       885.0       0.0     3.0  female  39.0    0.0    5.0  29.1250
# 887       886.0       0.0     2.0    male  27.0    0.0    0.0  13.0000
# 888       887.0       1.0     1.0  female  19.0    0.0    0.0  30.0000
# 889       888.0       0.0     3.0  female   NaN    1.0    2.0  23.4500
# 890       889.0       1.0     1.0    male  26.0    0.0    0.0  30.0000
#
#     embarked   class    who adult_male deck  embark_town alive  alone
# ...

# %%
df.rank()
# Out:
#      Unnamed: 0  survived  pclass    sex    age  sibsp  parch   fare  \
# 0           1.0     275.0   646.0  603.0  218.0  713.0  339.5   77.0
# 1           2.0     720.5   108.5  157.5  532.0  713.0  339.5  789.0
# 2           3.0     720.5   646.0  157.5  310.5  304.5  339.5  232.5
# 3           4.0     720.5   108.5  157.5  488.5  713.0  339.5  748.0
# 4           5.0     275.0   646.0  603.0  488.5  304.5  339.5  264.0
# ..          ...       ...     ...    ...    ...    ...    ...    ...
# 886       887.0     275.0   308.5  603.0  328.5  304.5  339.5  407.5
# 887       888.0     720.5   108.5  157.5  152.0  304.5  339.5  654.5
# 888       889.0     275.0   646.0  157.5    NaN  713.0  836.5  546.5
# 889       890.0     720.5   108.5  603.0  310.5  304.5  339.5  654.5
# 890       891.0     275.0   646.0  603.0  437.5  304.5  339.5  123.5
#
#      embarked  class    who  adult_male  deck  embark_town  alive  alone
# ...

# %%
df.cumsum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.cumsum of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
# ...

# %% [markdown]
# ## Group Data

# %%
df.size
# Out:
# 14256

# %% [raw]
# df.groupby()

# %%
df.groupby(['alive','age']).mean()
# Out:
#             Unnamed: 0  survived    pclass     sibsp     parch        fare  \
# alive age
# no    1.0   275.000000       0.0  3.000000  4.500000  1.500000   43.293750
#       2.0   301.428571       0.0  2.714286  2.714286  1.428571   44.439286
#       3.0   374.000000       0.0  3.000000  3.000000  1.000000   21.075000
#       4.0   361.333333       0.0  3.000000  3.666667  1.666667   29.433333
#       6.0   813.000000       0.0  3.000000  4.000000  2.000000   31.275000
# ...                ...       ...       ...       ...       ...         ...
# yes   58.0  158.000000       1.0  1.000000  0.000000  0.333333  108.844433
#       60.0  476.500000       1.0  1.000000  1.000000  0.500000   77.225000
#       62.0  699.500000       1.0  1.500000  0.000000  0.000000   45.250000
#       63.0  379.000000       1.0  2.000000  0.500000  0.000000   43.772900
#       80.0  630.000000       1.0  1.000000  0.000000  0.000000   30.000000
#
#             adult_male     alone
# alive age
# ...

# %%
df.groupby(['sex', 'fare']).mean()
# Out:
#                  Unnamed: 0  survived  pclass   age  sibsp  parch  adult_male  \
# sex    fare
# female 6.7500         654.0       0.0     3.0  18.0    0.0    0.0         0.0
#        7.2250         447.0       1.0     3.0  15.0    0.0    0.0         0.0
#        7.2292         573.5       1.0     3.0  13.0    0.0    0.0         0.0
#        7.2500         376.0       1.0     3.0  22.0    0.0    0.0         0.0
#        7.4958         786.0       1.0     3.0  18.0    0.0    0.0         0.0
# ...                     ...       ...     ...   ...    ...    ...         ...
# male   221.7792       527.0       0.0     1.0   NaN    0.0    0.0         1.0
#        227.5250       557.0       0.0     1.0   NaN    0.0    0.0         1.0
#        247.5208       118.0       0.0     1.0  24.0    0.0    1.0         1.0
#        263.0000       232.5       0.0     1.0  41.5    2.0    3.0         1.0
#        512.3292       708.0       1.0     1.0  35.5    0.0    0.5         1.0
#
# ...

# %%
df.agg
# Out:
# <bound method DataFrame.aggregate of      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...
